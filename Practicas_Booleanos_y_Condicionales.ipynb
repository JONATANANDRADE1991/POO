# %% [markdown]
# <a href="https://colab.research.google.com/github/JONATANANDRADE1991/POO/blob/main/Practicas_Booleanos_y_Condicionales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 50
b = 33
if b > a:
  print("b es más grande que a")
elif b==a:
  print("b es exactamente igual a a") 
else:
  print("b no es más grande que a")
# Out:
# b no es más grande que a

# %%
a = 10
b = 33
if a > b: print("a es mayor que b")
elif b==a: print("a es exactamente igual a b")
else: print("b es más grande que a")
# Out:
# b es más grande que a

# %%
print(ord('@'))
# Out:
# 64

# %%
name = "Pikachu"
strenght = 45
if name == "Charmander" or strenght == 23:
    print("Tu nombre es Charmander, y tienes 23 de fuerza.")
elif name == "Bulbasaur" or strenght == 50:
    print("Tu nombre es Balbasaur, y tienes 50 de fuerza.")
elif name == "Pikachu" or strenght == 45:
    print("Tu nombre es Pikachu, y tienes 45 de fuerza.")
# Out:
# Tu nombre es Pikachu, y tienes 45 de fuerza.

# %%
pokemons = ("Pikachu", "Squirtle","Charmander")
for x in pokemons:
    print(x)
# Out:
# Pikachu
# Squirtle
# Charmander

# %%
for lista in range(6):
    print(lista)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
list(range(7))
print(list)
# Out:
# <class 'list'>

# %%
count = 0
while True:
    print count
    count += 1
    if count >= 5:
        break

# %%
for x in range(10):
    # Chequéa si x es numero par
    if x % 2 == 0:
        continue
    print x

# %%
semilla = 1213

for i in range(3023):
  print(semilla)
  n1 = semilla**2
  n1 = str(n1)

  if len(n1)>4:
    n1 = int(n1[:4])
  else:
    n1 = int(n1[:-2][2:])
  semilla = n1
  break
# Out:
# 1213

# %%
semilla = 1213

for i in range(3023):
  print(semilla)
  n1 = semilla**2
  n1 = str(n1)

  if len(n1)>4:
    n1 = int(n1[:4])
  else:
    n1 = int(n1[:-2][1:])
  semilla = n1
# Out:
# 1213
# 1471
# 2163
# 4678
# 2188
# 4787
# 2291
# 5248
# 2754
# 7584
# 5751
# 3307
# 1093
# 1194
# 1425
# 2030
# 4120
# 1697
# 2879
# 8288
# 6869
# 4718
# 2225
# 4950
# 2450
# 6002
# 3602
# 1297
# 1682
# 2829
# 8003
# 6404
# 4101
# 1681
# 2825
# 7980
# 6368
# 4055
# 1644
# 2702
# 7300
# 5329
# 2839
# 8059
# 6494
# 4217
# 1778
# 3161
# 9991
# 9982
# 9964
# 9928
# 9856
# 9714
# 9436
# 8903
# 7926
# 6282
# 3946
# 1557
# 2424
# 5875
# 3451
# 1190
# 1416
# 2005
# 4020
# 1616
# 2611
# 6817
# 4647
# 2159
# 4661
# 2172
# 4717
# 2225
# 4950
# 2450
# 6002
# 3602
# 1297
# 1682
# 2829
# 8003
# 6404
# 4101
# 1681
# 2825
# 7980
# 6368
# 4055
# 1644
# 2702
# 7300
# 5329
# 2839
# 8059
# 6494
# 4217
# 1778
# 3161
# 9991
# 9982
# 9964
# 9928
# 9856
# 9714
# 9436
# 8903
# 7926
# 6282
# 3946
# 1557
# 2424
# 5875
# 3451
# 1190
# 1416
# 2005
# 4020
# 1616
# 2611
# 6817
# 4647
# 2159
# 4661
# 2172
# 4717
# 2225
# 4950
# 2450
# 6002
# 3602
# 1297
# 1682
# 2829
# 8003
# 6404
# 4101
# 1681
# 2825
# 7980
# ...
